# %% [markdown]
# # Web Scraping

# %%
! pip install beautifulsoup4 #Ignore this step if you alredy installed

# %%
! pip install requests #Ignore this step if you alredy installed

# %%
import sys
import time
import requests
from bs4 import BeautifulSoup

# %%
try:
    
    page = requests.get('https://www.cricbuzz.com/') #Add the link what u want

except Exception as e:
    
    error_type, error_obj, error_info =sys.exc_info()
    print('ERROR FOR LINK: ',url)
    print(error_type, 'Link',error_info.tb_lineno)

time.sleep(2) #Takes two milli-sec to request website to avoid blocking 
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})
#You will get this div & class when you click Ctrl + Shift + i (called as Inspect )in the Web-site
#If you want to get class of particular text in the website you need to click Ctrl + Shift + c then you do hover over on it.

# %%
page #If it runs it means the website is responding to our request
# Out:
# <Response [200]>

# %%
soup # We can aslo check soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links # We can aslo check links
# Out:
# [<div class="cb-nws-intr">KL Rahul, the India opener, who has achieved full fitness will also be eligible for the third Test</div>,
#  <div class="cb-nws-intr">The 36-year-old led in 36 of the 69 Tests he played for South Africa since the memorable debut in Adelaide in 2012</div>,
#  <div class="cb-nws-intr">A breakdown of the eight IPL squads, the issues and how they could be addressed on the auction table</div>,
#  <div class="cb-nws-intr">R Ashwin opens up about his plans to dismiss Ben Stokes, why he isn't surprised by Rishabh Pant's rise and his take on dealing with alien conditions</div>,
#  <div class="cb-nws-intr">In a year packed with cricket to help ECB recoup the losses they made due to covid-19, England's best all-format cricketers simply cannot do it all</div>,
#  <div class="cb-nws-intr">The South African board has written to the ICC requesting it to take the matter to the Disputes Resolution Committee</div>,
# ...

# %%
#To extract only Test from above html code we write a code for it.
for i in links:
    print(i.text)
    print('\n')
# Out:
# KL Rahul, the India opener, who has achieved full fitness will also be eligible for the third Test
#
#
# The 36-year-old led in 36 of the 69 Tests he played for South Africa since the memorable debut in Adelaide in 2012
#
#
# A breakdown of the eight IPL squads, the issues and how they could be addressed on the auction table
#
#
# R Ashwin opens up about his plans to dismiss Ben Stokes, why he isn't surprised by Rishabh Pant's rise and his take on dealing with alien conditions
#
#
# In a year packed with cricket to help ECB recoup the losses they made due to covid-19, England's best all-format cricketers simply cannot do it all
#
#
# The South African board has written to the ICC requesting it to take the matter to the Disputes Resolution Committee
#
#
# The Greenfield International Stadium, in Trivandrum, has already been allocated to host a two-week army recruitment rally in the ground, starting February 23
#
#
# The two teams will play 3 T20Is, 3 ODIs and 2 Tests
#
#
# ...
